# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import re
import untangle

# %%
chat = pd.read_csv("interaction_transcripts.csv", encoding = "ISO-8859-1")

# %%
chat.head()
# Out:
#                  ID  STATUS  ENTITYTYPEID MEDIATYPEID   TYPEID   SUBTYPEID  \
# 0  0006TaDR5FRF0VWR       2             2        chat  Inbound  InboundNew
# 1  0006TaDR5FRF126W       2             2        chat  Inbound  InboundNew
# 2  0006TaDR5FRF1X0S       2             2        chat  Inbound  InboundNew
# 3  0006TaDR5FRF266R       2             2        chat  Inbound  InboundNew
# 4  0006TaDR5FRF2687       2             2        chat  Inbound  InboundNew
#
#          EXTERNALID OWNERID         CONTACTID PARENTID   ...   INTATTRIBUTE1  \
# 0  00825B8EA88E58BC  (null)  0005NaD4X47N4V79   (null)   ...          (null)
# 1  00825B900ECC67A6  (null)  0005NaD4X47N4V79   (null)   ...          (null)
# 2  00825B995998BB59  (null)  0006TaDR5FRF1X0E   (null)   ...          (null)
# 3  00825B9BC596D3E3  (null)            (null)   (null)   ...          (null)
# 4  00825B9BC800D3FF  (null)  0006TaDR5FRF21U3   (null)   ...          (null)
#
# ...

# %%
#print(len(df.index))
#print(df.shape)
for index, row in chat.iterrows():
    if index == 57:    
        #print(row["STRUCTUREDTEXT"])
        text = row["STRUCTUREDTEXT"]
        #print(text)
        print('---------')    
        textRegex1 = re.compile(r'<msgText msgType= text  treatAs= NORMAL >(.*?)<\/msgText>')
        text1 = textRegex1.findall(text)
        print(text1)
        #print(text1.group())
        print('---------')    
        textRegex2 = re.compile(r'<msgText treatAs= NORMAL >(.*?)<\/msgText>')
        text2 = textRegex2.findall(text)
        print(text2)
        print('---------')        
    if index == 57:
        break
# Out:
# ---------
# ['  Topic: Program Information', 'I forget my airmiles number', 'no actually i did not use for long time', 'Airmiles number', 'yes sure', 'Liaqat Ali', 'liaqat104@yahoo.com / 2042535379 (old number)', 'Feb,01/1967', 'As i told you i did,t use for very long time i am not sure about ', 'no', '345-200 belvieu road winnipeg MB r2m 1t2 (old address)', 'currently I am at 5440 fudge terrace Mississauga ON l5m 0m8 but i used to live on Marion Street in past', 'just keep 2005 and cancel 2003', '647-216-2851   liaqat104@yahoo.com', 'ok', 'Thanks I really appriciate your help and support']
# ---------
# ...
